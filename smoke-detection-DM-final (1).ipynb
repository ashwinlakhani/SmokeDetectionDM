# %% [markdown]
# # This is a Data Mining Project by Ashwin Lakhani ( 2020UCO1570) & Aman Raj ( 2020UCO1508)
#
#
#  ### Smoke Detection

# %% [markdown]
# # Introduction
# <b>Context</b>
#
# A smoke detector is a device that senses smoke, typically as an indicator of fire. Smoke detectors are usually housed in plastic enclosures, typically shaped like a disk about 150 millimetres (6 in) in diameter and 25 millimetres (1 in) thick, but shape and size vary.
#
#
# <b>--> Types of Smoke Detectors</b>
#
# <b>- Photoelectric Smoke Detector</b>
# A photoelectric smoke detector contains a source of infrared, visible, or ultraviolet light, a lens, and a photoelectric receiver. In some types, the light emitted by the light source passes through the air being tested and reaches the photosensor. The received light intensity will be reduced due to scattering from particles of smoke, air-borne dust, or other substances; the circuitry detects the light intensity and generates an alarm if it is below a specified threshold, potentially due to smoke. Such detectors are also known as optical detectors.
#
# <b>-Ionization Smoke Detector</b>
# An ionization smoke detector uses a radioisotope to ionize air. If any smoke particles enter the open chamber, some of the ions will attach to the particles and not be available to carry the current in that chamber. An electronic circuit detects that a current difference has developed between the open and sealed chambers, and sounds the alarm
# The author of this dataset has successfully created a smoke detection device with the help of IOT devices and AI model. (Acknowledgement / Credits )
#
#
# <b>About the dataset</b>
#
# Collection of training data is performed with the help of IOT devices since the goal is to develop a AI based smoke detector device. Many different environments and fire sources have to be sampled to ensure a good dataset for training. A short list of different scenarios which are captured:
#
# - Normal indoor
# - Normal outdoor
# - Indoor wood fire, firefighter training area
# - Indoor gas fire, firefighter training area
# - Outdoor wood, coal, and gas grill
# - Outdoor high humidity
# etc.
#
#
# The dataset is nearly <b>60.000 readings<b> long. The sample rate is 1Hz for all sensors. To keep track of the data, a UTC timestamp is added to every sensor reading.
#
# The dataset contains air properties gotten from the proposed sorrounding of the experiment.
# The dataset has <b>16 columns<b> which are:
#
#
# <b>Columns:<b>
#
# 1. Unnamed:0 - Index
# 2. UTC - Timestamp UTC seconds
# 3. Temperature - Air temperature measured in Celsius
# 4. Humidity - Air humidity
# 5. TVOC - Total Volatile Organic Compounds; measured in ppb (parts per billion)
# 6. eCo2 - CO2 equivalent concentration; calculated from different values like TVCO
# 7. Raw H2 - Raw molecular hydrogen; not compensated (Bias, temperature, etc.)
# 8. Raw Ethanol - Raw ethanol gas
# 9. Pressure - Air pressure
# 10. PM1.0 - Paticulate matter of diameter less than 1.0 micrometer
# 11. PM2.5 - Paticulate matter of diameter less than 2.5 micrometer
# 12. NC0.5 - Concentration of particulate matter of diameter less than 0.5 micrometers
# 13. NC1.0 - Concentration of particulate matter of diameter less than 1.0 micrometers
# 14. NC2.5 - Concentration of particulate matter of diameter less than 2.5 micrometers
# 15. CNT - Simple Count
# 16. Fire Alarm - (Reality) 1 if there is fire and 0 if to fire
#
# <b> Acknowledgement / Credits <b>
# The data is collected by Stefan Blattmann in his project Real-time Smoke Detection with AI-based Sensor Fusion.
# Author's GitHub : https://github.com/Blatts01

# %% [markdown]
# ## Libraries

# %% [markdown]
# ### Importing basic libraries

# %%
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ## Importing the dataset

# %%
data = pd.read_csv('./SmokeDetectionDataset.csv')
data
# Out:
#        Unnamed: 0         UTC  Temperature[C]  Humidity[%]  TVOC[ppb]  \
# 0               0  1654733331          20.000        57.36          0
# 1               1  1654733332          20.015        56.67          0
# 2               2  1654733333          20.029        55.96          0
# 3               3  1654733334          20.044        55.28          0
# 4               4  1654733335          20.059        54.69          0
# ...           ...         ...             ...          ...        ...
# 62625       62625  1655130047          18.438        15.79        625
# 62626       62626  1655130048          18.653        15.87        612
# 62627       62627  1655130049          18.867        15.84        627
# 62628       62628  1655130050          19.083        16.04        638
# 62629       62629  1655130051          19.299        16.52        643
#
#        eCO2[ppm]  Raw H2  Raw Ethanol  Pressure[hPa]  PM1.0  PM2.5  NC0.5  \
# ...

# %% [markdown]
# ###  2. Feature Description:

# %% [markdown]
# #### UTC - Time at which observation was recorded.
# #### Temperature - Temperature of Surroundings in degree celsius.
# #### Humidity - air humidity during the observation
# #### TVOC - Total Volatile Organic Compounds present during the observation. Measured in ppb (parts per billion)
# #### eCo2 - CO2 equivalent concentration during the observation. Measured in ppm (parts per million)
# #### Raw H2 - The amount of Raw Hydrogen present in the surroundings during the observation.
# #### Raw Ethanol - The amount of Raw Ethanol present in the surroundings during the observation.
# #### Pressure - Air pressure measured during the observation in Pascal
# #### PM1.0 - Paticulate matter of diameter less than 1.0 micrometer .
# #### PM2.5 - Paticulate matter of diameter less than 2.5 micrometer.
# #### NC0.5 - Concentration of particulate matter of diameter less than 0.5 micrometers.
# #### NC1.0 - Concentration of particulate matter of diameter less than 1.0 micrometers.
# #### NC2.5 - Concentration of particulate matter of diameter less than 2.5 micrometers.
# #### CNT - Simple Count.
# #### Fire Alarm - Target variable If fire was present then value is 1 else it is 0.

# %% [markdown]
# ## Data Pre-Processing

# %% [markdown]
# ### 1) Checking for null values

# %%
data.isnull().sum()
# Out:
# Unnamed: 0        0
# UTC               0
# Temperature[C]    0
# Humidity[%]       0
# TVOC[ppb]         0
# eCO2[ppm]         0
# Raw H2            0
# Raw Ethanol       0
# Pressure[hPa]     0
# PM1.0             0
# PM2.5             0
# NC0.5             0
# NC1.0             0
# NC2.5             0
# CNT               0
# Fire Alarm        0
# dtype: int64

# %% [markdown]
# ### Observation: No Null values found in any columns

# %% [markdown]
# ## Checking for duplicate values

# %%
data.duplicated().sum()
# Out:
# 0

# %% [markdown]
# ### Observation : No duplicate values found

# %% [markdown]
# ### 2) Understanding the dataset

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 62630 entries, 0 to 62629
# Data columns (total 16 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Unnamed: 0      62630 non-null  int64
#  1   UTC             62630 non-null  int64
#  2   Temperature[C]  62630 non-null  float64
#  3   Humidity[%]     62630 non-null  float64
#  4   TVOC[ppb]       62630 non-null  int64
#  5   eCO2[ppm]       62630 non-null  int64
#  6   Raw H2          62630 non-null  int64
#  7   Raw Ethanol     62630 non-null  int64
#  8   Pressure[hPa]   62630 non-null  float64
#  9   PM1.0           62630 non-null  float64
#  10  PM2.5           62630 non-null  float64
#  11  NC0.5           62630 non-null  float64
#  12  NC1.0           62630 non-null  float64
#  13  NC2.5           62630 non-null  float64
#  14  CNT             62630 non-null  int64
#  15  Fire Alarm      62630 non-null  int64
# dtypes: float64(8), int64(8)
# memory usage: 7.6 MB

# %% [markdown]
# ### Observations :
# #### 1) We can infer that there are 16 columns with 62630 entries without any missing values.
# #### 2) All the columns are of numerical datatype(either float or integer) which means we do not have to do encoding.
# #### 3) Target or Dependent variable is 'Fire Alarm'.

# %% [markdown]
# ### Removing 'Unnamed:0' column as it is just a copy of index

# %%
data = data.drop(columns='Unnamed: 0',axis=1)

# %%
data.columns
# Out:
# Index(['UTC', 'Temperature[C]', 'Humidity[%]', 'TVOC[ppb]', 'eCO2[ppm]',
#        'Raw H2', 'Raw Ethanol', 'Pressure[hPa]', 'PM1.0', 'PM2.5', 'NC0.5',
#        'NC1.0', 'NC2.5', 'CNT', 'Fire Alarm'],
#       dtype='object')

# %% [markdown]
# # Exploratory Data Analysis (EDA)

# %%
data.describe()
# Out:
#                 UTC  Temperature[C]   Humidity[%]     TVOC[ppb]     eCO2[ppm]  \
# count  6.263000e+04    62630.000000  62630.000000  62630.000000  62630.000000
# mean   1.654792e+09       15.970424     48.539499   1942.057528    670.021044
# std    1.100025e+05       14.359576      8.865367   7811.589055   1905.885439
# min    1.654712e+09      -22.010000     10.740000      0.000000    400.000000
# 25%    1.654743e+09       10.994250     47.530000    130.000000    400.000000
# 50%    1.654762e+09       20.130000     50.150000    981.000000    400.000000
# 75%    1.654778e+09       25.409500     53.240000   1189.000000    438.000000
# max    1.655130e+09       59.930000     75.200000  60000.000000  60000.000000
#
#              Raw H2   Raw Ethanol  Pressure[hPa]         PM1.0         PM2.5  \
# count  62630.000000  62630.000000   62630.000000  62630.000000  62630.000000
# mean   12942.453936  19754.257912     938.627649    100.594309    184.467770
# ...

# %%
data.columns
# Out:
# Index(['UTC', 'Temperature[C]', 'Humidity[%]', 'TVOC[ppb]', 'eCO2[ppm]',
#        'Raw H2', 'Raw Ethanol', 'Pressure[hPa]', 'PM1.0', 'PM2.5', 'NC0.5',
#        'NC1.0', 'NC2.5', 'CNT', 'Fire Alarm'],
#       dtype='object')

# %% [markdown]
# ### Boxplot of all numerical features

# %%
# Lets define the continous columns
cont_col = ['UTC', 'Temperature[C]', 'Humidity[%]', 'TVOC[ppb]', 'eCO2[ppm]',
       'Raw H2', 'Raw Ethanol', 'Pressure[hPa]', 'PM1.0', 'PM2.5', 'NC0.5',
       'NC1.0', 'NC2.5','CNT']

#Plotting Graphs Before treating outliers of continous features
for col in cont_col:
    fig, ax =plt.subplots(1,constrained_layout=True)
    fig.set_size_inches(20, 3)
    sns.boxplot(data[col]).set(title="Boxplot")
    plt.suptitle(f'{col.title()} (Before handling outliers)',weight='bold')
    fig.show()

# %% [markdown]
# ### Observations:
#
# #### 1) We can observe outliers in UTC feature
# #### 2) Temparature and Humidity also has some datapoints which seems to be outliers,but they are very close to the 25th(Q1) and 75th quartile.(Q3). So we don't have to treat them as they are datapoint itself.
# #### 3)  Total Volatile Organic Compounds (TVOC) & eCO2 feature has many datapoints far away from the Q3. This needs to be treated.
# #### 4) Raw H2 and Raw Ethanol feature has many datapoints before Q1 which should be treated.
# #### 5) Raw ethanol also has data points before and after Q1 and Q3.
# #### 6) Pressure datapoints are fairly close to Q1, so no treatment is required.
# #### 7) Particulate Matter(PM) 1.0 and 2.5 have majority of points beyond Q3. Same is the case with Nc0.5,1.0 and 2.5. Outlier treatment should be done.

# %% [markdown]
# #### Performing outlier treatment

# %%
# Function to capping the outliers in numerical columns using IQR method
def outlier_handle(data, col_list):
    data_new = data.copy()
    for col_name in col_list:
        q1 = data[col_name].quantile(0.25)
        q3 = data[col_name].quantile(0.75)
        iqr = q3-q1  #Interquartile range
        fence_low  = q1-1.5*iqr
        fence_high = q3+1.5*iqr

        # Capping Outliers using IQR method
        data_new.loc[:,  col_name] = np.where(data[col_name]> fence_high, fence_high,
                                         np.where(data[col_name]< fence_low, fence_low,
                                                  data[col_name]))
    return data_new
data = outlier_handle(data, cont_col)

# %%
for col in cont_col:
    fig, ax =plt.subplots(1,constrained_layout=True)
    fig.set_size_inches(20, 3)
    
    sns.boxplot(data[col]).set(title="Boxplot")
    plt.suptitle(f'{col.title()} (After handling outliers)',weight='bold')
    fig.show()

# %% [markdown]
# ### Correlation check between Independent variables

# %%
plt.figure(figsize=(14,5))
sns.heatmap(data.corr(), annot = True,cmap='coolwarm')
plt.show()

# %% [markdown]
# ### Observations
#
# #### 1)We can observe high correlation between 'NC0.5', 'NC1.0', 'NC2.5','PM2.5'.(Above 0.75) So we remove these columns.
# #### 2) 'Raw Ethanol' and TVOC are also highly correlated. So we remove either one of the feature.
# #### 3) Remaining features are not correlated with any other.

# %% [markdown]
# #### Dropping correlated columns

# %%
data.drop(columns=['NC0.5', 'NC1.0', 'NC2.5','PM2.5','Raw Ethanol'],inplace=True)

# %% [markdown]
# #### Correlation Matrix after dropping correlated columns

# %%
plt.figure(figsize=(10,5))
sns.heatmap(data.corr(), annot = True,cmap='coolwarm')
plt.show()

# %% [markdown]
# #### Five point summary and data description of existing features

# %%
data.describe()
# Out:
#                 UTC  Temperature[C]   Humidity[%]     TVOC[ppb]     eCO2[ppm]  \
# count  6.263000e+04    62630.000000  62630.000000  62630.000000  62630.000000
# mean   1.654763e+09       16.206412     49.773158    773.275962    425.174725
# std    2.996534e+04       13.315496      4.902857    669.558671     37.460487
# min    1.654712e+09      -10.628625     38.965000      0.000000    400.000000
# 25%    1.654743e+09       10.994250     47.530000    130.000000    400.000000
# 50%    1.654762e+09       20.130000     50.150000    981.000000    400.000000
# 75%    1.654778e+09       25.409500     53.240000   1189.000000    438.000000
# max    1.654829e+09       47.032375     61.805000   2777.500000    495.000000
#
#              Raw H2  Pressure[hPa]         PM1.0           CNT    Fire Alarm
# count  62630.000000   62630.000000  62630.000000  62630.000000  62630.000000
# mean   12957.084009     938.820659      1.650188  10511.386157      0.714626
# ...

# %% [markdown]
# #### We can remove UTC and CNT as they are timestamp and simple count respectively and are not useful in prediction

# %%
data = data.drop(columns=['UTC','CNT'],axis=1)

# %%
data.head(2)
# Out:
#    Temperature[C]  Humidity[%]  TVOC[ppb]  eCO2[ppm]   Raw H2  Pressure[hPa]  \
# 0          20.000        57.36        0.0      400.0  12411.5        939.735
# 1          20.015        56.67        0.0      400.0  12411.5        939.744
#
#    PM1.0  Fire Alarm
# 0  0.065           0
# 1  0.065           0

# %% [markdown]
# #### Plotting histogram to see the feature distribution

# %%
data.hist(bins=10, figsize=(10,10))
plt.show()

# %% [markdown]
# #### Observation:
# #### 1) We can see that features have different values and different measurement units.
# #### 2) Scaling of the independent variables should be done to make the values easier for prediction.

# %% [markdown]
# ### Analysing the distribution of features and comparing it with the target variable(Fire Alarm)

# %%
sns.FacetGrid(data,hue='Fire Alarm',height=5).map(sns.distplot,'Temperature[C]').add_legend()

# %% [markdown]
# #### Observations:
# #### 1) Temparature range is from -10 to 50 degree celsius.
# #### 2) Fire Alarm goes off when the temparature is between 10 and 30 degree celsius.

# %%
sns.FacetGrid(data,hue='Fire Alarm',height=5).map(sns.distplot,'Humidity[%]').add_legend()

# %% [markdown]
# #### Observations:
# #### 1) Range of humidity is between 40 to 65.
# #### 2) Fire alarm is active maximum when humidity is in the range of 45 to 55.

# %%
sns.FacetGrid(data,hue='Fire Alarm',height=5).map(sns.distplot,'TVOC[ppb]').add_legend()

# %% [markdown]
# #### Observations:
# #### 1) Range of Volatile Organic Compounds is from -500  to 3000.
# #### 2) Alarm does not go off between -500 to 0.

# %%
sns.FacetGrid(data,hue='Fire Alarm',height=5).map(sns.distplot,'eCO2[ppm]').add_legend()

# %% [markdown]
# ####  Observations:
# #### 1) Range of eCO2 is between 380 and 500
# #### 2) Data is overlapping.

# %%
sns.FacetGrid(data,hue='Fire Alarm',height=5).map(sns.distplot,'Raw H2').add_legend()

# %% [markdown]
# #### Observations:
# #### 1) Range of raw hydrogen is betwwn 12400 and 13600.
# #### 2) Alarm rarely goes off when H2 is in between 12400 and 12800.
# #### 3) A gradual increase of alarm going off is observed when H2 is between 12800 and 13200.

# %%
sns.FacetGrid(data,hue='Fire Alarm',height=5).map(sns.distplot,'Pressure[hPa]').add_legend()

# %% [markdown]
# #### Observations:
# #### 1) Pressure range is between 935 and 940 Pascal
# #### 2) Alarm doesnt go off when pressure is at around 938 pascal but gradually goes off at around 938 to 940 pascal

# %%
sns.FacetGrid(data,hue='Fire Alarm',height=5).map(sns.distplot,'PM1.0').add_legend()

# %% [markdown]
# #### Observations:
# #### 1) Major overlap of data can be observed.

# %%
data['Fire Alarm'].value_counts()
# Out:
# 1    44757
# 0    17873
# Name: Fire Alarm, dtype: int64

# %%
ax=sns.countplot(x=data['Fire Alarm'],data=data)
ax.bar_label(ax.containers[0])
# Out:
# [Text(0, 0, '17873'), Text(0, 0, '44757')]

# %% [markdown]
# #### Observations:
# #### 1) Target variable has 17873 instance where alarm didn't go off and 44757 instances where alarm went off.

# %% [markdown]
# ### Splitting the data into independent and dependent variable

# %%
x = data.drop('Fire Alarm',axis=1)
y = data['Fire Alarm']

# %% [markdown]
# ### Scaling the independent variable using Standaradization

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
x_scaled = scaler.fit_transform(x)

# %%
pd.DataFrame(x_scaled)
# Out:
#               0         1         2         3         4         5         6
# 0      0.284903  1.547445 -1.154913 -0.672039 -2.826477  1.305845 -2.214593
# 1      0.286029  1.406710 -1.154913 -0.672039 -2.826477  1.318698 -2.214593
# 2      0.287080  1.261895 -1.154913 -0.672039 -2.826477  1.310129 -2.214593
# 3      0.288207  1.123199 -1.154913 -0.672039 -2.826477  1.307273 -2.214593
# 4      0.289333  1.002860 -1.154913 -0.672039 -2.826477  1.318698 -2.214593
# ...         ...       ...       ...       ...       ...       ...       ...
# 62625  0.167595 -2.204479 -0.221455 -0.672039  2.955122 -1.710473 -1.425258
# 62626  0.183741 -2.204479 -0.240871 -0.672039  2.955122 -1.710473 -1.453199
# 62627  0.199813 -2.204479 -0.218468 -0.672039  2.955122 -1.710473 -1.509081
# 62628  0.216035 -2.204479 -0.202039 -0.672039  2.955122 -1.710473 -1.509081
# 62629  0.232257 -2.204479 -0.194571 -0.672039  2.955122 -1.710473 -1.509081
#
# [62630 rows x 7 columns]

# %% [markdown]
# #### Splitting the data into training and testing

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x_scaled, y, train_size=0.75, random_state=101)
print(x_train.shape)
print(x_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (46972, 7)
# (15658, 7)
# (46972,)
# (15658,)

# %% [markdown]
# ### Building a model using Logistic Regression

# %%
from sklearn.linear_model import LogisticRegression
lr = LogisticRegression()
lr.fit(x_train, y_train)
# Out:
# LogisticRegression()

# %%
y_pred_lr_train = lr.predict(x_train)
y_pred_lr_test = lr.predict(x_test)

# %% [markdown]
# ### Evaluation of model using various evaluation metrics

# %%
from sklearn.metrics import classification_report, plot_confusion_matrix, accuracy_score

# %% [markdown]
# ### Accuracy Score

# %%
print('Training Accuracy :',accuracy_score(y_train, y_pred_lr_train)*100)
print('Testing Accuracy :',accuracy_score(y_test, y_pred_lr_test)*100)
# Out:
# Training Accuracy : 88.47185557353316
# Testing Accuracy : 88.75335291863584

# %% [markdown]
# ### Classification Report

# %%
print(classification_report(y_test, y_pred_lr_test))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.89      0.69      0.78      4462
#            1       0.89      0.96      0.92     11196
#
#     accuracy                           0.89     15658
#    macro avg       0.89      0.83      0.85     15658
# weighted avg       0.89      0.89      0.88     15658

# %% [markdown]
# ### Confusion Matrix

# %%
plot_confusion_matrix(lr,x_test, y_test)
plt.show()

# %% [markdown]
# #### Observations:
# #### 1) We got 88% training accuracy and same testing accuracy. We can use other classification algorithms to improve the accuracy score.
# #### 2) The model has predicted 0 as 0 3099 times and 1 as 1 10798 times.
# #### 3) However wrong predictions are also high as the model predicted 1 as 0 398 times and 0 as 1 1363 times.

# %% [markdown]
# ### Building a model using DecisionTreeClassifier with splitting criterion gini

# %%
from sklearn.tree import DecisionTreeClassifier
dt1 = DecisionTreeClassifier(criterion='gini')
dt1.fit(x_train, y_train)
# Out:
# DecisionTreeClassifier()

# %% [markdown]
# ### Building a model using DecisionTreeClassifier with splitting criterion entropy

# %%
dt2 = DecisionTreeClassifier(criterion='entropy')
dt2.fit(x_train, y_train)
# Out:
# DecisionTreeClassifier(criterion='entropy')

# %% [markdown]
# ### Prediction of Decision Tree Models

# %%
y_pred_train = dt1.predict(x_train)
y_pred_test = dt1.predict(x_test)

# %%
y_pred_train_1 = dt2.predict(x_train)
y_pred_test_1 = dt2.predict(x_test)

# %% [markdown]
# ### Evaluation of Decision Tree Models

# %% [markdown]
# #### Accuracy Score

# %%
print('Training Accuracy of DT Model using gini:',accuracy_score(y_train, y_pred_train)*100)
print('Training Accuracy of DT Model using entropy:',accuracy_score(y_train, y_pred_train_1)*100)
# Out:
# Training Accuracy of DT Model using gini: 100.0
# Training Accuracy of DT Model using entropy: 100.0

# %%
print('Testing Accuracy of DT Model using gini:',accuracy_score(y_test, y_pred_test)*100)
print('Testing Accuracy of DT Model using entropy :',accuracy_score(y_test, y_pred_test_1)*100)
# Out:
# Testing Accuracy of DT Model using gini: 99.94890790650147
# Testing Accuracy of DT Model using entropy : 99.98084046493804

# %% [markdown]
# #### Classification Report

# %%
print(classification_report(y_test, y_pred_test))

print("#####"*14)

print(classification_report(y_test, y_pred_test_1))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      4462
#            1       1.00      1.00      1.00     11196
#
#     accuracy                           1.00     15658
#    macro avg       1.00      1.00      1.00     15658
# weighted avg       1.00      1.00      1.00     15658
#
# ######################################################################
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      4462
#            1       1.00      1.00      1.00     11196
#
#     accuracy                           1.00     15658
#    macro avg       1.00      1.00      1.00     15658
# weighted avg       1.00      1.00      1.00     15658

# %% [markdown]
# ### Confusion Matrix

# %%
from sklearn.metrics import plot_confusion_matrix
plot_confusion_matrix(dt1,x_test, y_test)
plt.show()

# %% [markdown]
# #### Observations:
# #### 1) We got 100% training accuracy and 99.9% testing accuracy.
# #### 2) The model has predicted 0 as 0 4461 times and 1 as 1 11191 times.
# #### 3) Wrong predictions are comparitively low as the model predicted 1 as 0 only 5 times and 0 as 1 only 1 time.

# %%
from sklearn.metrics import plot_confusion_matrix
plot_confusion_matrix(dt2,x_test, y_test)
plt.show()

# %% [markdown]
# #### Observations:
# #### 1) We got 100% training accuracy and 99.9% testing accuracy.
# #### 2) The model has predicted 0 as 0 4461 times and 1 as 1 11195 times.
# #### 3) Wrong predictions are comparitively low as the model predicted 1 as 0 only 1 times and 0 as 1 only 1 time.
#
# ### Hence we can conclude that Decision Tree Model with entropy splitting criterion provides us a better prediction.

# %% [markdown]
# ### Feature importance calculation for Decision Tree model

# %%
feat_dict= {}
for col, val in sorted(zip(x.columns, dt1.feature_importances_),key=lambda x:x[1],reverse=True):
  feat_dict[col]=val

# %%
feat_df = pd.DataFrame({'Feature':feat_dict.keys(),'Importance':feat_dict.values()})
feat_df
# Out:
#           Feature  Importance
# 0   Pressure[hPa]    0.486141
# 1       TVOC[ppb]    0.256425
# 2           PM1.0    0.175213
# 3     Humidity[%]    0.028998
# 4       eCO2[ppm]    0.027047
# 5  Temperature[C]    0.022132
# 6          Raw H2    0.004045

# %% [markdown]
# ### Plotting the feature importance in a bar graph

# %%
values = feat_df.Importance    
idx = feat_df.Feature
plt.figure(figsize=(5,5))
sns.barplot(y=idx,x=values).set(title='Important features to predict fire alarm')
plt.show()

# %% [markdown]
# ### Observations:
# #### 1) Pressure is the important variable for predicting fire alarm in decision tree model. (48%)
# #### 2) Raw Hydrogen is the least contributing feature for prediction(0.6%)

# %% [markdown]
# ### Building a model using RandomForestClassifier

# %%
from sklearn.ensemble import RandomForestClassifier
rf1 = RandomForestClassifier(n_estimators=200,criterion='gini')
rf1.fit(x_train,y_train)
# Out:
# RandomForestClassifier(n_estimators=200)

# %%
y_pred_rf_train1 = rf1.predict(x_train)
y_pred_rf_test1 = rf1.predict(x_test)

# %%
print('Training Accuracy :',accuracy_score(y_train, y_pred_rf_train1)*100)
print('Testing Accuracy :',accuracy_score(y_test, y_pred_rf_test1)*100)
# Out:
# Training Accuracy : 100.0
# Testing Accuracy : 99.96806744156342

# %%
print(classification_report(y_test, y_pred_rf_test1))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      4462
#            1       1.00      1.00      1.00     11196
#
#     accuracy                           1.00     15658
#    macro avg       1.00      1.00      1.00     15658
# weighted avg       1.00      1.00      1.00     15658

# %%
from sklearn.metrics import plot_confusion_matrix
plot_confusion_matrix(rf1,x_test, y_test)
plt.show()

# %% [markdown]
# #### Observations:
# #### 1) We got 100% training accuracy and 99.9% testing accuracy.
# #### 2) The model has predicted 0 as 0 4461 times and 1 as 1 11193 times.
# #### 3) Wrong predictions are comparitively low as the model predicted 1 as 0 only 3 times and 0 as 1 only 2 time.
#
# ### We can observe that Decision Tree and RandomForest Model gives similar prediction result

# %% [markdown]
# ### Feature importance calculation for Random Forest model

# %%
feat_dict= {}
for col, val in sorted(zip(x.columns, rf1.feature_importances_),key=lambda x:x[1],reverse=True):
  feat_dict[col]=val

# %%
feat_df = pd.DataFrame({'Feature':feat_dict.keys(),'Importance':feat_dict.values()})
feat_df
# Out:
#           Feature  Importance
# 0   Pressure[hPa]    0.265142
# 1       TVOC[ppb]    0.239069
# 2     Humidity[%]    0.166228
# 3           PM1.0    0.116203
# 4          Raw H2    0.107993
# 5  Temperature[C]    0.075577
# 6       eCO2[ppm]    0.029788

# %% [markdown]
# ### Plotting the feature importance in a bar graph

# %%
values = feat_df.Importance    
idx = feat_df.Feature
plt.figure(figsize=(5,5))
sns.barplot(y=idx,x=values).set(title='Important features to predict fire alarm')
plt.show()

# %% [markdown]
# ### Observation:
# #### 1) TVOC is the largest contributor in predicting the fire alarm
# #### 2) CO2 is the least important feature.

# %% [markdown]
# ## Conclusion
#
# ####  1) Dataset initially consisted of 62630 rows and 16 columns.
# ####  2) Data Preprocessing, Data Cleaning and Exploratory Data Analysis were performed on features to gain insights.
# ####  3) Data Distribution and comparison with the target variable gave us an insight about the distribution of data compared to the target variable.
# #### 4) Model building was done using 3 algorithms. Logistic Regression, Decision Tree Classifier and Random Forest Classifier.  In which Decision Tree Classifier and Random Forest Classifier gave us maximum accuracy. (99%)
# #### 5) Feature importance was also performed in Decision Tree and RandomForest Models and the results were plotted using a barplot.
#
# #### Hence we can go with either DecisionTree or RandomForest Model.
